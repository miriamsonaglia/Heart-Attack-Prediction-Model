# %%
import pandas as pd
CHINA_DATASET = "heart_attack_china.csv"
US_DATASET = "heart_attack_us.csv"
INDIA_DATASET = "heart_attack_india.csv"
INDONESIA_DATASET = "heart_attack_indonesia.csv"
china = pd.read_csv(CHINA_DATASET, sep=",")
unitedStates = pd.read_csv(US_DATASET, sep=",")
india = pd.read_csv(INDIA_DATASET, sep=",")
indonesia = pd.read_csv(INDONESIA_DATASET, sep=",")

# %%
china['State'] = "China"
india['State'] = "India"
unitedStates['State'] = "United States"
indonesia['State'] = "Indonesia"

unitedStates["PatientID"] = range(1, len(unitedStates)+1)
indonesia["PatientID"] = range(1, len(indonesia)+1)

# %%
(
    unitedStates.drop(
        columns = ['EducationLevel',
                   'ST_Depression',
                   'EmploymentStatus',
                   'MaritalStatus', 
                   'Ethnicity',
                   'Medication',
                   'ChestPainType',
                   'ECGResults',
                   'ExerciseInducedAngina',
                   'Slope',
                   'NumberOfMajorVessels',
                   'Thalassemia',
                   'StrokeHistory',
                   'Residence',
                   'MaxHeartRate',
                   'HeartRate'
                  ],
        inplace=True
    )
)

# %%
unitedStates.rename(columns = {'BMI':'Obesity', 'Income':'IncomeLevel', 'Patient_ID':'PatientID', 'Diet':'HealthyDiet'}, inplace=True)

# %%
(
    china.drop(
        columns = ['Education_Level',
                   'Employment_Status',
                   'Air_Pollution_Exposure',
                   'Healthcare_Access',
                   'Rural_or_Urban',
                   'Region',
                   'Province',
                   'Hospital_Availability',
                   'TCM_Use',
                   'Chronic_Kidney_Disease',
                   'CVD_Risk_Score'
                  ],
        inplace=True
    )
)

# %%
china.rename(
    columns = { 
        'Patient_ID':'PatientID',
        'Smoking_Status':'Smoker',
        'Cholesterol_Level':'Cholesterol',
        'Physical_Activity': 'PhysicalActivity',
        'Diet_Score':'HealthyDiet',
        'Income_Level':'IncomeLevel',
        'Blood_Pressure':'BloodPressure',
        'Previous_Heart_Attack': 'PreviousHeartAttack',
        'Family_History_CVD': 'FamilyHistory',
        'Stress_Level':'StressLevel',
        'Alcohol_Consumption': 'AlcoholConsumption',
        'Heart_Attack' : 'Outcome'
    },
    inplace=True
)

# %%
(
    india.drop(
        columns = ['State_Name',
                   'Triglyceride_Level',
                   'LDL_Level',
                   'HDL_Level',
                   'Diastolic_BP',
                   'Air_Pollution_Exposure',
                   'Healthcare_Access',
                   'Emergency_Response_Time',
                   'Health_Insurance'
                  ],
        inplace=True
    )
)

# %%
india.rename(
    columns = {
        'Patient_ID':'PatientID',
        'Smoking':'Smoker',
        'Alcohol_Consumption': 'AlcoholConsumption',
        'Physical_Activity': 'PhysicalActivity',
        'Diet_Score':'HealthyDiet',
        'Cholesterol_Level':'Cholesterol',
        'Systolic_BP':'BloodPressure',
        'Family_History':'FamilyHistory',
        'Stress_Level':'StressLevel',
        'Heart_Attack_History':'PreviousHeartAttack',
        'Annual_Income':'IncomeLevel',
        'Heart_Attack_Risk':'Outcome'
    },
    inplace=True
)

# %%
(
    indonesia.drop(
        columns = ['region',
                   'waist_circumference',
                   'air_pollution_exposure',
                   'sleep_hours',
                   'blood_pressure_diastolic',
                   'fasting_blood_sugar',
                   'cholesterol_hdl',
                   'cholesterol_ldl',
                   'triglycerides',
                   'EKG_results',
                   'medication_usage',
                   'participated_in_free_screening'
                  ],
        inplace=True
    )
)

# %%
indonesia.rename(
    columns = {
        'age':'Age',
        'gender':'Gender',
        'income_level': 'IncomeLevel',
        'hypertension':'Hypertension',
        'diabetes':'Diabetes',
        'cholesterol_level':'Cholesterol',
        'obesity':'Obesity',
        'family_history':'FamilyHistory',
        'smoking_status':'Smoker',
        'alcohol_consumption':'AlcoholConsumption',
        'physical_activity':'PhysicalActivity',
        'dietary_habits':'HealthyDiet',
        'stress_level':'StressLevel',
        'blood_pressure_systolic':'BloodPressure',
        'previous_heart_disease':'PreviousHeartAttack',
        'heart_attack':'Outcome',
    },
    inplace=True
)

# %%
dfs = {
    "China": china,
    "India": india,
    "United States": unitedStates,
    "Indonesia" : indonesia
}

# insieme di tutte le colonne
all_columns = set().union(*(df.columns for df in dfs.values()))

# colonne mancanti per ogni dataset
diff_columns = {
    name: sorted(all_columns - set(df.columns))
    for name, df in dfs.items()
}

diff_columns
# Out:
# {'China': [], 'India': [], 'United States': [], 'Indonesia': []}

# %%
china['Gender'] = china['Gender'].astype('category')
china['Smoker'] = china['Smoker'].map({'Smoker':True, 'Non-Smoker':False}).astype('bool') # MIRI ADDED
china["Hypertension"] = china["Hypertension"].map({"Yes": True, "No": False}).astype('bool') # CONTROLLARE DB (TUTTE TRUE)
china["Diabetes"] = china["Diabetes"].map({"Yes": True, "No": False}).astype('bool') # CONTROLLARE DB (TUTTE TRUE)
china["Obesity"] = china["Obesity"].map({"Yes": True, "No": False}).astype('bool') # CONTROLLARE DB (TUTTE TRUE)
china['Cholesterol'] = china['Cholesterol'].astype('category')
# PhysicalActivity here --> to bool
# HealthyDiete here --> to bool
china['StressLevel'] = china['StressLevel'].astype('category')
china['AlcoholConsumption'] = china['AlcoholConsumption'].map({'Yes':True, 'No':False}).astype('bool') # MIRI ADDED
china['FamilyHistory'] = china['FamilyHistory'].map({'Yes':True, 'No':False}).astype('bool') # MIRI ADDED
# IncomeLevel here --> to categoric
china['PreviousHeartAttack'] = china['PreviousHeartAttack'].map({'Yes':True, 'No':False}).astype('bool') # MIRI ADDED
china['Outcome'] = china['Outcome'].map({'Yes':True, 'No':False}).astype('bool') # MIRI ADDED

china.head(10)
# Out:
#    PatientID  Age  Gender  Smoker  Hypertension  Diabetes  Obesity  \
# 0          1   55    Male   False         False     False     True
# 1          2   66  Female    True          True     False    False
# 2          3   69  Female    True         False     False    False
# 3          4   45  Female    True         False      True    False
# 4          5   39  Female    True         False     False    False
# 5          6   76    Male    True         False     False    False
# 6          7   37    Male    True         False     False    False
# 7          8   88    Male   False          True     False     True
# 8          9   54  Female    True         False     False     True
# 9         10   47  Female    True         False     False     True
#
#   Cholesterol PhysicalActivity HealthyDiet StressLevel  AlcoholConsumption  \
# 0      Normal             High    Moderate         Low                True
# 1         Low             High     Healthy      Medium               False
# 2         Low             High    Moderate         Low               False
# 3      Normal              Low     Healthy      Medium                True
# 4      Normal           Medium     Healthy         Low               False
# 5         Low              Low        Poor      Medium               False
# 6      Normal              Low        Poor      Medium               False
# 7         Low              Low    Moderate        High               False
# 8      Normal           Medium        Poor      Medium               False
# 9         Low              Low    Moderate      Medium                True
#
#    FamilyHistory IncomeLevel  BloodPressure  PreviousHeartAttack  Outcome  \
# 0          False         Low            104                False    False
# 1           True      Middle            142                False    False
# 2          False        High            176                False    False
# 3          False         Low            178                 True    False
# 4          False      Middle            146                False    False
# 5           True      Middle             92                False    False
# 6           True        High            144                False    False
# 7          False         Low            162                False    False
# 8          False         Low             93                False    False
# 9           True        High            125                False     True
#
#    State
# 0  China
# 1  China
# 2  China
# 3  China
# 4  China
# 5  China
# 6  China
# 7  China
# 8  China
# 9  China

# %%
# MIRI DID THIS

unitedStates['Gender'] = unitedStates['Gender'].astype('category')
# Cholesterol --> to categoric 
# Obesity --> to bool
unitedStates['Smoker'] = unitedStates['Smoker'].map({1:True, 0:False}).astype('bool')
unitedStates['Diabetes'] = unitedStates['Diabetes'].map({1:True, 0:False}).astype('bool')
unitedStates['Hypertension'] = unitedStates['Hypertension'].map({1:True, 0:False}).astype('bool')
unitedStates['FamilyHistory'] = unitedStates['FamilyHistory'].map({1:True, 0:False}).astype('bool')
# PhysicalActivity here --> to bool
# AlcoholConsumption here --> to bool
# HealthyDiet here --> to bool
# StressLevel here --> to categoric
# IncomeLevel here --> to categoric
unitedStates['PreviousHeartAttack'] = unitedStates['PreviousHeartAttack'].map({1:True, 0:False}).astype('bool')
unitedStates['Outcome'] = unitedStates['Outcome'].map({'Heart Attack':True, 'No Heart Attack':False}).astype('bool')

unitedStates.head(10)
# Out:
#    Age  Gender  Cholesterol  BloodPressure  Obesity  Smoker  Diabetes  \
# 0   31    Male          194            162     22.9    True      True
# 1   69    Male          208            148     33.9    True      True
# 2   34  Female          132            161     34.0    True      True
# 3   53    Male          268            134     35.0    True      True
# 4   57  Female          203            140     30.1    True      True
# 5   41    Male          158            154     38.7    True      True
# 6   45  Female          237            168     21.7    True      True
# 7   61  Female          218            113     23.1    True      True
# 8   45    Male          216            114     24.8    True      True
# 9   30    Male          143            130     24.7    True      True
#
#    Hypertension  FamilyHistory  PhysicalActivity  AlcoholConsumption  \
# 0          True           True                 6                   0
# 1          True           True                 1                   2
# 2          True           True                 1                   3
# 3          True           True                 6                   0
# 4          True           True                 4                   1
# 5          True           True                 3                   2
# 6          True           True                 0                   2
# 7          True           True                 4                   4
# 8          True           True                 2                   4
# 9          True           True                 6                   2
#
#   HealthyDiet  StressLevel  IncomeLevel  PreviousHeartAttack  Outcome  \
# 0   Unhealthy            1        64510                 True    False
# 1   Unhealthy            6        91773                 True    False
# 2     Healthy            3       173550                 True     True
# 3     Healthy            3        43861                 True    False
# 4    Moderate            1        83404                 True     True
# 5    Moderate            4       113011                 True     True
# 6     Healthy            5        61069                 True    False
# 7     Healthy            5        74686                 True    False
# 8   Unhealthy            2       148763                 True     True
# 9    Moderate            3       184885                 True    False
#
#            State  PatientID
# 0  United States          1
# 1  United States          2
# 2  United States          3
# 3  United States          4
# 4  United States          5
# 5  United States          6
# 6  United States          7
# 7  United States          8
# 8  United States          9
# 9  United States         10

# %%
# PER VERIFICARE LE COLONNE
india['Hypertension'].dtype
# Out:
# dtype('int64')

# %%
# MIRI DID THIS

india['Gender'] = india['Gender'].astype('category')
india['Diabetes'] = india['Diabetes'].map({1:True, 0:False}).astype('bool')
india['Hypertension'] = india['Hypertension'].map({1:True, 0:False}).astype('bool')
# Cholesterol --> to categoric 
# Obesity --> to bool
#unitedStates['Smoker'] = unitedStates['Smoker'].map({1:True, 0:False}).astype('bool')
#unitedStates['FamilyHistory'] = unitedStates['FamilyHistory'].map({1:True, 0:False}).astype('bool')
# PhysicalActivity here --> to bool
# AlcoholConsumption here --> to bool
# HealthyDiet here --> to bool
# StressLevel here --> to categoric
# IncomeLevel here --> to categoric
#unitedStates['PreviousHeartAttack'] = unitedStates['PreviousHeartAttack'].map({1:True, 0:False}).astype('bool')
#unitedStates['Outcome'] = unitedStates['Outcome'].map({'Heart Attack':True, 'No Heart Attack':False}).astype('bool')

india.head(10)
# Out:
#    PatientID  Age  Gender  Diabetes  Hypertension  Obesity  Smoker  \
# 0          1   42  Female      True         False        1       1
# 1          2   26    Male      True         False        0       0
# 2          3   78    Male      True         False        1       0
# 3          4   58    Male      True         False        1       0
# 4          5   22    Male      True         False        0       0
# 5          6   31    Male      True         False        0       0
# 6          7   26    Male      True         False        0       0
# 7          8   68    Male      True         False        1       0
# 8          9   45  Female      True         False        0       0
# 9         10   52    Male      True         False        0       1
#
#    AlcoholConsumption  PhysicalActivity  HealthyDiet  Cholesterol  \
# 0                   0                 0            9          248
# 1                   1                 1            4          272
# 2                   0                 1            6          268
# 3                   0                 1            9          224
# 4                   0                 1            5          277
# 5                   0                 0            7          188
# 6                   0                 0            9          210
# 7                   0                 0            2          160
# 8                   0                 0            3          264
# 9                   0                 0            1          167
#
#    BloodPressure  FamilyHistory  StressLevel  PreviousHeartAttack  \
# 0             93              0            4                    0
# 1            134              0            7                    0
# 2            104              1           10                    0
# 3             91              0            1                    1
# 4            141              0            9                    0
# 5            110              1            3                    0
# 6            156              0            6                    0
# 7            157              0           10                    0
# 8            158              0            7                    0
# 9            166              0            6                    1
#
#    IncomeLevel  Outcome  State
# 0       611025        0  India
# 1       174527        0  India
# 2      1760112        0  India
# 3      1398213        0  India
# 4        97987        1  India
# 5       399442        0  India
# 6      1021445        0  India
# 7       157215        0  India
# 8       798426        0  India
# 9      1505931        0  India

# %%
# PatientID (integer), Age (integer), Gender (categoric), Smoker (bool), Hypertension (bool), Diabetes (bool), Obesity (BMI conversion from number to bool),
# Cholesterol (from number to categoric), PhisicalActivity (from * to bool), HealthyDiet (from * to bool),
# StressLevel (from * to categoric), AlcoholConsumption (from * to bool), FamilyHistory (bool), IncomeLevel (from * to categoric)
# BloodPressure (integer), PreviousHearthAttack (bool), Outcome (bool).

# %%
#china.set_index(['Stato','Patient_ID'], inplace=True)
#unitedStates.set_index(['Stato','Patient_ID'], inplace=True)
#india.set_index(['Stato','Patient_ID'], inplace=True)
#indonesia.set_index(['Stato','Patient_ID'], inplace=True)
#dataset = pd.concat([china, india, unitedStates, indonesia], verify_integrity=True)
